# %%
# import 'pickle' to save and load Python objects (like models, encoders)
import pickle

# import 'numpy' for working with numerical arrays and data
import numpy as np

# %%
# load the saved pipeline from the file for later use (e.g., making predictions)
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
# create a sample test input with 7 features to predict survival
# format: [Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, '5'], dtype=object).reshape(1, 7)

# %%
# use the saved pipeline to predict survival for the new test input
pipe.predict(test_input2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
